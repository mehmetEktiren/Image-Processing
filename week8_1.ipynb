# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
im_1=plt.imread('kus.jpeg')
im_1.ndim,type(im_1),im_1.shape
# Out:
# (3, numpy.ndarray, (1080, 1440, 3))

# %%
im_1[100,100,:]
# Out:
# array([5, 5, 7], dtype=uint8)

# %%
m,n,p=im_1.shape
m,n,p
# Out:
# (1080, 1440, 3)

# %%
plt.imshow(im_1)
plt.show()

# %%
new_image=np.zeros((m,n),dtype=float)

# %%
for i in range(m):
    for j in range (n):
        s=(im_1[i,j,0]+im_1[i,j,1]+im_1[i,j,2])/3
        new_image[i,j]=s
# Out:
# C:\Users\hemeD\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: RuntimeWarning: overflow encountered in ubyte_scalars
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
plt.imshow(new_image)
plt.show()

# %%
plt.imshow(new_image)
plt.show()

# %%
m,n,p=im_1.shape
m,n,p
# Out:
# (28, 28, 3)

# %%
plt.imshow(im_1)
plt.show()

# %%
new_image=np.zeros((m,n),dtype=float)
for i in range(m):
    for j in range (n):
        s=(im_1[i,j,0]+im_1[i,j,1]+im_1[i,j,2]/3)
        new_image[i,j]=s
# Out:
# C:\Users\hemeD\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: RuntimeWarning: overflow encountered in ubyte_scalars
#   after removing the cwd from sys.path.

# %%
plt.imshow(new_image,cmap='gray')
plt.show()

# %%
im_3=im_1+im_2
plt.imshow(im_3)
plt.show()
